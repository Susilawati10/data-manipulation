# %% [markdown]
# #Assignment Guidance: Data Manipulation

# %%
# --- Data Manipulation ----
import pandas as pd
pd.set_option("display.max_columns",None)

#--- Numerical Computation ----
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %cd "/content/"
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
# Out:
# /content

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
#--- data understanding ---
df.info()

#TotalCharges harusnya float64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
#merubah data type object menjadi float64
df["TotalCharges"]=pd.to_numeric(df["TotalCharges"], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %% [markdown]
# #Soal
# #1. Buat fungsi Python untuk memfilter churn untuk menemukan pelanggan yang berisiko tinggi.Pelanggan berisiko tinggi didefinisikan sebagai pelanggan yang memiliki kontrak bulanan dan tagihan bulanan yang tinggi (di atas persentil 90%).

# %%
#kontrak bulanan
df.Contract.value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
#dari pelanggan yang memiliki kontrak bulanan dan tagihan bulanan yang tinggi (di atas persentil 90%).
df.diatas_persentil_90 = df["MonthlyCharges"] > df["MonthlyCharges"].quantile(0.9)
df.diatas_persentil_90
# Out:
# <ipython-input-202-d094054daeb3>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.diatas_persentil_90 = df["MonthlyCharges"] > df["MonthlyCharges"].quantile(0.9)
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039     True
# 7040    False
# 7041    False
# 7042     True
# Name: MonthlyCharges, Length: 7043, dtype: bool

# %%
df.query("MonthlyCharges > MonthlyCharges.quantile(0.9)").copy()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# ...          ...     ...            ...     ...        ...     ...
# 7022  7203-OYKCT    Male              0      No         No      72
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7034  0639-TSIQW  Female              0      No         No      67
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 8             Yes           Yes     Fiber optic             No           No
# ...

# %%
#fungsi Python untuk memfilter churn untuk menemukan pelanggan yang berisiko tinggi
condition = (df["Churn"]=="Yes") & (df["MonthlyCharges"] > df["MonthlyCharges"].quantile(0.9))


df[
    condition
]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 8     7892-POOKP  Female              0     Yes         No      28
# 13    0280-XJGEX    Male              0      No         No      49
# 38    5380-WJKOV    Male              0      No         No      34
# 104   3192-NQECA    Male              0     Yes         No      68
# 171   1875-QIVME  Female              0     Yes         No       2
# ...          ...     ...            ...     ...        ...     ...
# 6918  8267-ZNYVZ  Female              0     Yes         No      33
# 6952  6394-MFYNG  Female              0      No         No      48
# 6972  6664-FPDAC  Female              1      No         No      56
# 7006  0093-XWZFY    Male              0      No         No      40
# 7034  0639-TSIQW  Female              0      No         No      67
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 8             Yes           Yes     Fiber optic             No           No
# ...

# %% [markdown]
# #2.Buat script Python untuk mengelompokkan data berdasarkan jenis kontrak dan menghitung rata-rata tagihan bulanan serta persentase churn untuk setiap grup (1 dan 0, rata rata untuk menghitung persentase)

# %%
#mengitung mean tagihan bulanan serta persentase churn untuk setiap grup
df.groupby("Contract").agg(
 {
     "MonthlyCharges" : "mean"
 }
)
# Out:
#                 MonthlyCharges
# Contract
# Month-to-month       66.398490
# One year             65.048608
# Two year             60.770413

# %%
#Menghitung persentase churn untuk setiap grup
df.groupby("Contract")["Churn"].value_counts()
# Out:
# Contract        Churn
# Month-to-month  No       2220
#                 Yes      1655
# One year        No       1307
#                 Yes       166
# Two year        No       1647
#                 Yes        48
# Name: count, dtype: int64

# %%
df_churn = pd.to_numeric(df["Churn"].replace({"Yes": 1, 'No': 0}))

# %%
df_churn.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
df.groupby("Churn").agg(
    {
        'Churn':"count"
    }
)
# Out:
#        Churn
# Churn
# No      5174
# Yes     1869

# %%
df_churn = pd.to_numeric(df['Churn'].replace({'Yes': 1, 'No': 0}))

# %%
df["Churn"]  = df["Churn"].map({
    "Yes":1,
    "No":0
})

# %%
df_churn.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
df.groupby("Contract").agg(
    {
        'Churn':"sum"
    }
)
# Out:
#                 Churn
# Contract
# Month-to-month   1655
# One year          166
# Two year           48

# %%
#Persentase Churn = (jumlah Churn / Total Customer) * 100%
Month_to_month = (1655 / 7043) * 1
print(Month_to_month)

One_year = (166 / 7043) * 1
print(One_year)

Two_year = (48 / 7043) * 1
print(Two_year)
# Out:
# 0.2349850915802925
# 0.02356950163282692
# 0.006815277580576459

# %% [markdown]
# #Soal 3:
# #Buat pivot table untuk menganalisis hubungan antara jenis kontrak dan metode pembayaran terhadap rata-rata tagihan bulanan.

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# ...

# %%
#menganalisis hubungan antara jenis kontrak dan metode pembayaran terhadap rata-rata tagihan bulanan
df.pivot_table(
    index="Contract",
    columns="PaymentMethod",
    values="MonthlyCharges",
    aggfunc='mean'
)
# Out:
# PaymentMethod   Bank transfer (automatic)  Credit card (automatic)  \
# Contract
# Month-to-month                  69.085399                67.678821
# One year                        67.484143                67.972362
# Two year                        65.013918                64.422117
#
# PaymentMethod   Electronic check  Mailed check
# Contract
# Month-to-month         74.989486     46.050056
# One year               79.095245     44.306380
# Two year               84.335714     38.587304

# %% [markdown]
# #Soal 4
# #Buat crosstab untuk mengevaluasi hubungan antara churn dan metode pembayaran, serta menghitung persentase churn untuk setiap metode pembayaran.

# %%
crosstab = pd.crosstab(df['Churn'], df['PaymentMethod'])
crosstab
# Out:
# PaymentMethod  Bank transfer (automatic)  Credit card (automatic)  \
# Churn
# 0                                   1286                     1290
# 1                                    258                      232
#
# PaymentMethod  Electronic check  Mailed check
# Churn
# 0                          1294          1304
# 1                          1071           308

# %%
#menghitung churn persentase untuk setiap metode pembayaran
crosstab = pd.crosstab(df['Churn'], df['PaymentMethod'], normalize='index')
crosstab
# Out:
# PaymentMethod  Bank transfer (automatic)  Credit card (automatic)  \
# Churn
# 0                               0.248550                 0.249324
# 1                               0.138042                 0.124131
#
# PaymentMethod  Electronic check  Mailed check
# Churn
# 0                      0.250097      0.252029
# 1                      0.573034      0.164794

# %% [markdown]
# ###penjelasn churn 0 dan 1
#
# -Churn 0 menunjukan pelangan yang tetap
#
# -Churn 1 menunjukan pelangan yang churn (berhenti langganan)

# %% [markdown]
# #Soal 5
# #Buat aggregation untuk mengevaluasi total churn dengan senior citizen yes dan dependents lebih dari 0, serta menghitung total churn dari gender dengan kontrak year.

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
#total churn dengan senior citizen dan dependents
df.groupby(["SeniorCitizen","Dependents"])["Churn"].value_counts()
# Out:
# SeniorCitizen  Dependents  Churn
# 0              No          0        2793
#                            1        1089
#                Yes         0        1715
#                            1         304
# 1              No          0         597
#                            1         454
#                Yes         0          69
#                            1          22
# Name: count, dtype: int64

# %%
#aggregation untuk evaluasi total churn dengan senior citizen yes dan dependents = "Yes"
condition1 = df["Churn"].sum()
print(condition)

condition2 = df["SeniorCitizen"] == 1
condition3 = df["Dependents"] == "Yes"

df_filtered = df[condition1 & condition2 & condition3]
print(df_filtered)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Length: 7043, dtype: bool
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# 72    1891-QRQSA    Male              1     Yes        Yes      64
# 140   3146-MSEGF  Female              1     Yes        Yes      72
# 308   3167-SNQPL    Male              1     Yes        Yes      38
# ...          ...     ...            ...     ...        ...     ...
# 6235  5180-UCIIQ    Male              1     Yes        Yes      22
# 6346  9661-MHUMO    Male              1     Yes        Yes       1
# 6446  2205-LPVGL    Male              1     Yes        Yes      58
# 6451  4868-AADLV    Male              1     Yes        Yes      66
# ...

# %%
#memfilter churn dengan seniorcitizen "yes" dan dependents > 0
filter_citizen = df[(df["SeniorCitizen"] == 1) & (df["Dependents"] == "Yes")]
filter_citizen
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 54    4667-QONEA  Female              1     Yes        Yes      60
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# 72    1891-QRQSA    Male              1     Yes        Yes      64
# 140   3146-MSEGF  Female              1     Yes        Yes      72
# 308   3167-SNQPL    Male              1     Yes        Yes      38
# ...          ...     ...            ...     ...        ...     ...
# 6235  5180-UCIIQ    Male              1     Yes        Yes      22
# 6346  9661-MHUMO    Male              1     Yes        Yes       1
# 6446  2205-LPVGL    Male              1     Yes        Yes      58
# 6451  4868-AADLV    Male              1     Yes        Yes      66
# 6763  7471-MQPOS    Male              1     Yes        Yes      71
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 54            Yes                No             DSL            Yes
# ...

# %%
filter_citizen.groupby("Churn").agg({
    'Churn':"count"
}).rename(columns={"Churn":"Total Churn"})
# Out:
#        Total Churn
# Churn
# 0               69
# 1               22

# %%
#menghitung total churn dari gender dengan kontrak year
df.groupby(["gender","Contract"])["Churn"].value_counts()
# Out:
# gender  Contract        Churn
# Female  Month-to-month  0        1083
#                         1         842
#         One year        0         643
#                         1          75
#         Two year        0         823
#                         1          22
# Male    Month-to-month  0        1137
#                         1         813
#         One year        0         664
#                         1          91
#         Two year        0         824
#                         1          26
# Name: count, dtype: int64

# %%
#memfilter gender Male dan contract month to month
filter_gender = df[(df["gender"] == "Male") & (df["Contract"] == "Month-to-month")]
filter_gender
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 2     3668-QPYBK   Male              0      No         No       2
# 6     1452-KIOVK   Male              0      No        Yes      22
# 10    9763-GRSKD   Male              0     Yes        Yes      13
# 13    0280-XJGEX   Male              0      No         No      49
# 14    5129-JLPIS   Male              0      No         No      25
# ...          ...    ...            ...     ...        ...     ...
# 7027  0550-DCXLH   Male              0      No         No      13
# 7032  6894-LFHLY   Male              1      No         No       1
# 7033  9767-FFLEM   Male              0      No         No      38
# 7035  8456-QDAVC   Male              0      No         No      19
# 7041  8361-LTMKD   Male              1     Yes         No       4
#
#      PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 2             Yes            No             DSL            Yes          Yes
# ...

# %%
filter_gender.groupby("gender").agg({
    'Churn':"count",
    'Contract':"count"
}).rename(columns={"Churn":"Total Churn"})
# Out:
#         Total Churn  Contract
# gender
# Male           1950      1950
